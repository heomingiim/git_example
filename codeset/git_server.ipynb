# %%
a=3
b=5
a+b
# Out:
# 8

# %%
import pandas as pd

# %%
#exception
try:
    inDf = pd.read_csv("./dataset/sample.txt")
    inDf
except Exception as e:
    print(e)
# Out:
#   regionid   qty
# 0      A01   100

# %%
#load .env 파일 가져오기
